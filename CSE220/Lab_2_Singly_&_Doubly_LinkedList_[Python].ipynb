# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # **Singly Linked List**

# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# **You must Run this cell for your driver code to Singly LL tasks to execute successfully**

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# **Task 1:** Alternate Merge

# %%
def alternate_merge(head1, head2):
  temp_1 = head1
  temp_2 = head2
  while temp_1 != None and temp_2 != None:
    next_1 = temp_1.next
    next_2 = temp_2.next
    temp_1.next = temp_2
    temp_2.next = next_1
    temp_1 = next_1
    temp_2 = next_2
  return head1


print('==============Test Case 1=============')
head1 = createList(np.array([1,2,6,8,11]))
head2 = createList(np.array([5,7,3,9,4]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    1 --> 5 --> 2 --> 7 --> 6 --> 3 --> 8 --> 9 --> 11 --> 4


print('==============Test Case 2=============')
head1 = createList(np.array([5, 3, 2, -4]))
head2 = createList(np.array([-4, -6, 1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    5 → -4 -> 3 → -6 -> 2 -> 1 -> -4


print('==============Test Case 3=============')
head1 = createList(np.array([4, 2, -2, -4]))
head2 = createList(np.array([8, 6, 5, -3]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print   4-> 8 → 2-> 6 → -2 → 5 → -4 -> -3
# Out:
# ==============Test Case 1=============
# Linked List 1:
# 1-->2-->6-->8-->11
#
# Linked List 2:
# 5-->7-->3-->9-->4
#
# Merged Linked List:
# 1-->5-->2-->7-->6-->3-->8-->9-->11-->4
#
# ==============Test Case 2=============
# Linked List 1:
# 5-->3-->2-->-4
#
# Linked List 2:
# -4-->-6-->1
#
# Merged Linked List:
# 5-->-4-->3-->-6-->2-->1-->-4
#
# ==============Test Case 3=============
# Linked List 1:
# 4-->2-->-2-->-4
#
# Linked List 2:
# 8-->6-->5-->-3
#
# Merged Linked List:
# 4-->8-->2-->6-->-2-->5-->-4-->-3

# %% [markdown]
# **Task 2:** Word Decoder

# %%
def counter(head):
  count = 0
  temp = head
  while temp != None:
    count += 1
    temp = temp.next
  return count

def word_Decoder(head):
  temp = head
  length = counter(head)
  val_idx = 13%length
  value_inc = val_idx
  idx = 0
  new_head = Node(None)
  while temp != None:
    if idx == val_idx:
      if new_head.next == None:
        new_head.next = Node(temp.elem)
        val_idx+= value_inc
      else:
        hold = new_head.next
        new_head.next = Node(temp.elem)
        new_head.next.next = hold
        val_idx+= value_inc

    idx += 1
    temp = temp.next

  return new_head



#Driver Code
print('==============Test Case 1=============')
head = createList(np.array(['B', 'M', 'D', 'T', 'N', 'O', 'A', 'P', 'S', 'C']))
print("Encoded Word:")
printLinkedList(head) #This should print B→M→D→T→N→O→A→P→S→C

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→C→A→T

print('==============Test Case 2=============')

head = createList(np.array(['Z', 'O', 'T', 'N', 'X']))
print("Encoded Word:")
printLinkedList(head) #This should print Z→O→T→N→X

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→N
# Out:
# ==============Test Case 1=============
# Encoded Word:
# B-->M-->D-->T-->N-->O-->A-->P-->S-->C
#
# Decoded Word:
# None-->C-->A-->T
#
# ==============Test Case 2=============
# Encoded Word:
# Z-->O-->T-->N-->X
#
# Decoded Word:
# None-->N

# %% [markdown]
# **Task 3:** ID Generator

# %%
def idGenerator(head1, head2, head3):
  temp1 = head1
  temp2 = head2
  temp3 = head3
  new_head = None
  while temp1 != None and temp2 != None and temp3 != None:
    n = temp1.next
    temp1.next = new_head
    new_head = temp1
    temp1 = n
    temp2.elem = (temp2.elem + temp3.elem)%10
    temp2 = temp2.next
    temp3 = temp3.next


  new_temp = new_head
  while new_temp != None:
   if new_temp.next == None:
     new_temp.next = head2
     break
   new_temp = new_temp.next

  return new_head



print('==============Test Case 1=============')
head1 = createList(np.array([0,3,2,2]))
head2 = createList(np.array([5,2,2,1]))
head3 = createList(np.array([4,3,2,1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print  2 → 2 → 3 → 0 → 9 → 5 → 4 → 2


print('==============Test Case 2=============')
head1 = createList(np.array([0,3,9,1]))
head2 = createList(np.array([3,6,5,7]))
head3 = createList(np.array([2,4,3,8]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print 1 → 9 → 3 → 0 → 5 → 0 → 8 → 5
# Out:
# ==============Test Case 1=============
# Linked List 1:
# 0-->3-->2-->2
#
# Linked List 2:
# 5-->2-->2-->1
#
# Linked List 3:
# 4-->3-->2-->1
#
# New ID:
# 2-->2-->3-->0-->9-->5-->4-->2
#
# ==============Test Case 2=============
# Linked List 1:
# 0-->3-->9-->1
#
# Linked List 2:
# 3-->6-->5-->7
#
# Linked List 3:
# 2-->4-->3-->8
#
# New ID:
# 1-->9-->3-->0-->5-->0-->8-->5

# %% [markdown]
# # **Doubly Linked List**

# %% [markdown]
# For this part, you should write your full code in the following cells along with your driver codes on your own.

# %%
class Patient:
  #write a constructor
  def __init__(self, id, name, age, bloodgroup, next, prev):
    self.id = id
    self.name = name
    self.age = age
    self.bloodgroup = bloodgroup
    self.next = next
    self.prev = prev

# %%
class WRM:

  def __init__(self):
    self.dh = Patient(None,None,None,None,None,None)
    self.dh.next = self.dh
    self.dh.prev = self.dh

  def registerPatient(self,id, name, age, bloodgroup):
    new_node = Patient(id, name,age, bloodgroup,None,None)
    new_node.next = self.dh
    new_node.prev = self.dh.prev
    self.dh.prev.next = new_node
    self.dh.prev = new_node
    print(f"{name} has been resgistered")

  def servePatient(self):
    if self.dh.next == self.dh:
        print("No Patient to be served")
        return

    first_node = self.dh.next
    print(f"{first_node.name} has been served")
    self.dh.next = first_node.next
    first_node.next.prev = self.dh

  def showAllPatient(self):
    if self.dh.next == self.dh:
      print("There are no patient in the WRM .")

    else:
      current = self.dh.next
      while current != self.dh:
        if current.next != self.dh:
          print(current.name,"-->",end=" ")
        else:
          print(current.name)
        current = current.next

  def canDoctorGoHome(self):
    if self.dh.next == self.dh:
      print("YES")
    else:
      print("NO")

  def cancelAll(self):
    if self.dh.next == self.dh:
        print("There are no patient left")
        return
    current = self.dh.next

    while current != self.dh:
        temp = current
        current = current.next
        temp.prev = None
        temp.next = None

    self.dh.next = self.dh
    self.dh.prev = self.dh
    print("All the appointments have been canceled")

  def ReverseTheLine(self):
    if self.dh.next == self.dh:
      print("There are no patient in the WRM .")
      return
    current = self.dh
    while True:
      temp = current.next
      current.next = current.prev
      current.prev = temp
      current = temp

      if current == self.dh:
        break

        self.dh.next = self.dh.prev
        self.dh.prev = self.dh.next


    print("The line has been reveresed")

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")
def WRM_RUNNER():
  WRM_SYSTEM = WRM()
  while True:
    print("====CHOOSE AN OPTION====")
    print("1. registerPatient()")
    print("2. servePatient() ")
    print("3. cancelAll()")
    print("4. canDoctorGoHome() ")
    print("5. showAllPatient()")
    print("6. ReverseTheLine()")
    print("7. EXIT")
    print("========================")
    print()
    INPUT = int(input("ENTER YOUR CHOICE  "))
    if INPUT == 1:
      print("Excecuting registerPatient()")
      print()
      id = int(input("Id? "))
      name = input("NAME? ")
      age = int(input("Age? "))
      bloodgroup = input("Blood Group? ")
      patient = WRM_SYSTEM.registerPatient(id,name,age,bloodgroup)
      print()
    elif INPUT ==2:
      print("EXCECUTING servePatient()")
      print()
      WRM_SYSTEM.servePatient()
      print()
    elif INPUT ==3:
      print("EXCECUTING cancelAll()")
      print()
      WRM_SYSTEM.cancelAll()
      print()
    elif INPUT ==4:
      print("EXCECUTING canDoctorGoHome()")
      print()
      WRM_SYSTEM.canDoctorGoHome()
      print()
    elif INPUT ==5:
      print("EXCECUTING showAllPatient()")
      print()
      WRM_SYSTEM.showAllPatient()
      print()
    elif INPUT ==6:
      print("EXCECUTING ReverseTheLine()")
      print()
      WRM_SYSTEM.ReverseTheLine()
      print()
    elif INPUT ==7:
      print("THANKS FOR USING WRM SYSTEM")
      print()
      print("EXITING.....")
      break
    else:
      print()
      print("THERE ARE NO SUCH OPERATION")
      print()

WRM_RUNNER()
# Out:
# **Welcome to Waiting Room Management System**
# ====CHOOSE AN OPTION====
# 1. registerPatient()
# 2. servePatient()
# 3. cancelAll()
# 4. canDoctorGoHome()
# 5. showAllPatient()
# 6. ReverseTheLine()
# 7. EXIT
# ...
#
# ENTER YOUR CHOICE  1
# Excecuting registerPatient()
#
# Id? 01
# NAME? Prohor
# Age? 24
# Blood Group? O+
# Prohor has been resgistered
#
# ====CHOOSE AN OPTION====
# 1. registerPatient()
# 2. servePatient()
# 3. cancelAll()
# 4. canDoctorGoHome()
# 5. showAllPatient()
# 6. ReverseTheLine()
# 7. EXIT
# ...
#
# ENTER YOUR CHOICE  5
# EXCECUTING showAllPatient()
#
# Prohor
#
# ====CHOOSE AN OPTION====
# 1. registerPatient()
# 2. servePatient()
# 3. cancelAll()
# 4. canDoctorGoHome()
# 5. showAllPatient()
# 6. ReverseTheLine()
# 7. EXIT
# ...
#
# ENTER YOUR CHOICE  1
# Excecuting registerPatient()
#
# Id? 02
# NAME? Samia
# Age? 22
# Blood Group? O+
# Samia has been resgistered
#
# ====CHOOSE AN OPTION====
# 1. registerPatient()
# 2. servePatient()
# 3. cancelAll()
# 4. canDoctorGoHome()
# ...
